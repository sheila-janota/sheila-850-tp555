# %%
# Import all the necessary libraries...
import random
import matplotlib.pyplot as plt
import math
import numpy as np
import functools
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from IPython.core.display import display, HTML

# %matplotlib inline

np.random.seed(32)

"""
Generate data points for plotting the error surface.
"""
def calculateErrorSurface(y, x1, x2):
    # Generate values for parameters.
    N = 200
    a1 = np.linspace(-12.0, 14.0, N)
    a2 = np.linspace(-12.0, 14.0, N)

    A1, A2 = np.meshgrid(a1, a2)

    # Generate points for plotting the cost-function surface.
    J = np.zeros((N,N))
    for iter1 in range(0, N):
        for iter2 in range(0, N):
            yhat = A1[iter1][iter2]*x1 + A2[iter1][iter2]*x2
            J[iter1][iter2] = (1/M)*np.sum( np.square(y - yhat)  )
            
    return J, A1, A2


"""
Calculate closed-form solution using the normal equation.
"""
def calculateClosedFormSolution(X, x1, x2):
    # Closed-form solution.
    a_opt = np.linalg.pinv(np.transpose(X).dot(X)).dot(np.transpose(X).dot(y))
    yhat = a_opt[0, 0]*x1 + a_opt[1, 0]*x2
    Joptimum = (1/M)*np.sum(np.power((y - yhat), 2) )

    return Joptimum, a_opt


"""
Stocastic gradient descent solution.
"""
def StocasticGradientDescent(alpha, n_epochs, X_b, y):
    
    # Random initialization of parameters.
    a = np.random.randn(2,1)
    a[0] = -10;
    a[1] = -10;

    # Create vector for parameter history.
    a_hist = np.zeros((2, n_epochs*M+1))
    # Initialize history vector.
    a_hist[0, 0] = a[0]
    a_hist[1, 0] = a[1]
    
    grad_hist = np.zeros((2, n_epochs*M))

    # Stocastic gradient-descent loop.   
    for epoch in range(n_epochs):
        for i in range(M):
            random_index = np.random.randint(M)
            xi = X[random_index:random_index+1]
            yi = y[random_index:random_index+1]
            gradients = -2*xi.T.dot(yi - xi.dot(a))
            grad_hist[0, epoch*M+i] = gradients[0]
            grad_hist[1, epoch*M+i] = gradients[1]
            a = a - alpha * gradients
            a_hist[0, epoch*M+i+1] = a[0]
            a_hist[1, epoch*M+i+1] = a[1]
            Jgd[epoch*M+i+1] = (1/M)*sum(np.power( (y - X.dot(a)) , 2))

    return a, a_hist, Jgd

"""
Hypothesis Function
"""
def h(X_b, a):
    return a.T.dot(X_b.T)


#-----------------------------------------------------------------------

# Define the number of examples.
M = 1000
# Constant learning rate.
alpha =  0.0099
# Number of epochs.
n_epochs = 1


# Generate target function.
x1 = np.random.normal(0,1,(M, 1))
x2 = np.random.normal(0,1,(M, 1))
w = np.random.normal(0,1,(M, 1))
y = 2*x1 + 2*x2 + w

# Concatenate both column vectors, x1 and x2.
X = np.c_[x1, x2]
X_b = X

a = np.random.randn(2,1)

# Create array for storing error values.
Jgd = np.zeros(n_epochs*M+1)
Jgd[0] = (1/M)*sum(np.power(y - X.dot(a), 2))


# Calculate data point for plotting error surface.
J, A1, A2 = calculateErrorSurface(y, x1, x2)

# Calculate closed-form solution.
Joptimum, a_opt = calculateClosedFormSolution(X_b, x1, x2)

# Run Stocastic gradient-descent algorithm.
a, a_hist, Jgd = StocasticGradientDescent(alpha, n_epochs, X_b, y)

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

x1Aux = np.concatenate( x1, axis=0 )
x2Aux = np.concatenate( x2, axis=0 )
yAux = np.concatenate( y, axis=0 )

ax.scatter(x1Aux, x2Aux, yAux)
xl = []
yl = []
ln, = plt.plot(xl, yl, 'r--', animated=True, label='h(x)')
plt.title('Função Hipótese')

def init():
    ax.set_xlabel('x')  # Adiciona uma label ao eixo x.
    ax.set_ylabel('y')  # Adiciona uma label ao eixo y.
    ax.set_zlabel('z')  # Adiciona uma label ao eixo z.
    return ln,

def update(frame):
    theta = np.zeros((2,1))
    theta[0] = a_hist[0,frame]
    theta[1] = a_hist[1,frame]
    f = functools.partial(h, a=theta)
    yAux2 = f(X_b)
    ln.set_data_3d(x1Aux, x2Aux, yAux2)
    return ln,

# Create animated figure.
ani = FuncAnimation(fig, update, frames=200, init_func=init, blit=False, interval=300)
# Display the animated figure.
display(HTML(ani.to_html5_video()))
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Plot cost-function surface.
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(A1, A2, J, cmap=cm.coolwarm, linewidth=0, antialiased=False)
# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_xlabel('$a_0$', fontsize=14)
ax.set_ylabel('$a_1$', fontsize=14)
ax.set_zlabel('$J_e$', fontsize=14);
plt.title('Superfície de Erro')
ax.view_init(20, 45)
#Show the plot.
plt.show()

# %%
# Plot figure.        
fig = plt.figure(figsize=(7,7))
cp = plt.contour(A1, A2, J)
plt.clabel(cp, inline=1, fontsize=10)
plt.xlabel('$a_1$', fontsize=14)
plt.ylabel('$a_2$', fontsize=14)
plt.title('Superfície de Contorno')
plt.plot(a_opt[0], a_opt[1], c='r', marker='*')
plt.plot(a_hist[0, :], a_hist[1, :], 'kx')
plt.xticks(np.arange(-10, 14, step=2.0))
plt.yticks(np.arange(-10, 14, step=2.0))
plt.show()

#plt.savefig("error_contour_sgd.png", dpi=600)

# %%
fig = plt.figure(figsize=(7,7))

plt.plot(np.arange(0, n_epochs*M), Jgd[0:n_epochs*M])
plt.xlim((0, n_epochs*M))
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('$J_e$')
plt.title('Iteração vs. Erro')
plt.grid()
plt.show()

#plt.savefig("error_vs_iteration_bgd.png", dpi=600)

# %% [markdown]
# **Questão 5f) Resporta:**
#  Com base nas representções gráficas anteriores posso dizer que o Gráfico da superfície de contorno do Batch mostra
#  uma superfície circular.
#  Atingiu o ponto ótimo após 1000 iterações, e o gráfico de iteração vs. erro deu um valor constante próximo de 1
#  Foi necessário ajustar o Alpha para se atingir um erro aceitável e superfície de contorno legível, ou seja
#  foi preciso diminuir a taxa de aprendizagem aos poucos para que o algoritmo se estabilize no mínimo global.
