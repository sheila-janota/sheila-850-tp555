# %%
# Reference: https://www.ritchieng.com/machine-learning-multinomial-naive-bayes-vectorization/

# Import all necessary libraries.
import pandas as pd
import numpy as np
from sklearn.naive_bayes import BernoulliNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Features.
x_train = np.array(['free great offer if you join, a great offer for free!',
'great offer for free delivery',
'uber is promoting a great offer for free',
'try uber for free for your 1st ride',
'earn your uber 10 credit for free by applying for the uber visa credit card',
'uber receipt'])

# Labels.
y_train = np.array(['spam','spam','spam','ham','ham','ham'])

# Test Features.
x_test = np.array(['Moonnight Trial', 'Limited offer: Free & Great Deal'])

# %%
# Convert a collection of text documents into a matrix of token counts.
vect = CountVectorizer(binary=True)

# Learn the vocabulary dictionary and return term-document matrix.
# This is equivalent to fit followed by transform, but more efficiently implemented.
X_train_dtm = vect.fit_transform(x_train)

# %%
# Instantiate a Bernoulli Naive Bayes model.
nb_model = BernoulliNB(binarize=None)

# %%
# Train the MultinomialNB model.
nb_model.fit(X_train_dtm, y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=None, class_prior=None, fit_prior=True)

# %%
# Transform document into document-term matrix- dtm.
X_test_dtm = vect.transform(x_test)
# Perform classification on an array of test vectors X_test_dtm.
y_pred_class = nb_model.predict(X_test_dtm)
print(y_pred_class)
# Out:
# ['ham' 'spam']

# %%
print(nb_model.predict_proba(X_test_dtm))
# Out:
# [[0.65498652 0.34501348]
#  [0.0027732  0.9972268 ]]

# %%
print('A Mensagem "Moonnight Trial" pertence - a classe ham, pois apresenta maior probabilidade:0.65498652')
print('A Mensagem "Limited offer: Free & Great Deal" pertence - a classe spam, pois apresenta maior probabilidade:0.9972268')
# Out:
# A Mensagem "Moonnight Trial" pertence - a classe ham, pois apresenta maior probabilidade:0.65498652
# A Mensagem "Limited offer: Free & Great Deal" pertence - a classe spam, pois apresenta maior probabilidade:0.9972268
