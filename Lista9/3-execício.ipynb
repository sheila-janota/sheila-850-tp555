# %%
# Import all necessary libraries.
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_blobs(n_samples=150, n_features=2, centers=5, cluster_std=1.0, shuffle=True, random_state=42)

# %%
km = KMeans(n_clusters=4)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(X[:,0], X[:,1])
plt.title('Dados de treinamento')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()

# %%
C1 = []
C2 = []
print('Valores ótimos para os Centroids:')
for i in range(0,4):
    C1.append(km.cluster_centers_[i][0])
    C2.append(km.cluster_centers_[i][1])
    print('C%d: (%1.2f, %1.2f)' % (i,km.cluster_centers_[i][0],km.cluster_centers_[i][1]))
# Out:
# Valores ótimos para os Centroids:
# C0: (-8.90, 7.43)
# C1: (3.45, 2.99)
# C2: (-7.02, -6.59)
# C3: (-2.76, 8.82)

# %%
print('Para treinar o modelo foram necessárias',km.n_iter_,'iterações')
# Out:
# Para treinar o modelo foram necessárias 2 iterações

# %%
idx0 = np.argwhere(km.labels_ == 0)
idx1 = np.argwhere(km.labels_ == 1)
idx2 = np.argwhere(km.labels_ == 2)
idx3 = np.argwhere(km.labels_ == 3)
idx4 = np.argwhere(km.labels_ == 4)

fig = plt.figure(figsize=(5,5))
plt.plot(X[idx0,0], X[idx0,1], '.', label='Class 0')
plt.plot(X[idx1,0], X[idx1,1], 'x', label='Class 1')
plt.plot(X[idx2,0], X[idx2,1], '*', label='Class 2')
plt.plot(X[idx3,0], X[idx3,1], 'v', label='Class 3')
plt.plot(X[idx4,0], X[idx4,1], '^', label='Class 4')
plt.plot(C1,C2, 'P', label='Centroids')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Clusters a que cada dado de treinamento pertence')
plt.legend()
plt.show()
